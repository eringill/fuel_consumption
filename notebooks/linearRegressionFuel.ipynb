# %%
import pandas as pd
import os
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# %%
all_types = pd.read_csv('all_types.csv')

# %%
all_types['fuel'].unique()
# Out:
# array(['electricity', 'gas', 'diesel', 'ethanol', nan], dtype=object)

# %%
gas_only = all_types.loc[all_types['fuel'] == 'gas' ]

# %%
fit = stats.linregress(gas_only['co2_rating'], gas_only['engine_size'])
print("Fitted value of the co2_rating and engine_size:",
      "\n\tr2value -> ", str((fit.rvalue)**2),
     )
# Out:
# Fitted value of the co2_rating and engine_size:
# 	r2value ->  0.56890750347766

# %%
sns.set(style="darkgrid")
sns.lmplot(x='engine_size', y='co2_rating', data=gas_only);

# %%
gas_only_corr = gas_only.corr()
trimask = np.triu(np.ones_like(gas_only_corr, dtype=bool))

plt.figure(figsize=(10,6))
sns.heatmap(gas_only_corr, cmap='coolwarm', mask=trimask)
plt.show()
# Out:
# <ipython-input-19-1a06dd801616>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gas_only_corr = gas_only.corr()

# %%
diesel_only = all_types.loc[all_types['fuel'] == 'diesel' ]

# %%
diesel_only_corr = diesel_only.corr()
trimask = np.triu(np.ones_like(diesel_only_corr, dtype=bool))

plt.figure(figsize=(10,6))
sns.heatmap(diesel_only_corr, cmap='coolwarm', mask=trimask)
plt.show()
# Out:
# <ipython-input-21-e338a4a503db>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   diesel_only_corr = diesel_only.corr()
